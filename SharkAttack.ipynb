# %% [markdown]
# Shark Attack!

# %%
#Importaciones:
import pandas as pd
import numpy as np

# %%
#Para subir el archivo Attacks:
attack = pd.read_csv('Input/attacks.csv',encoding = 'latin-1')
display(attack)
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
for col in attack.columns: 
    print(col)
# Out:
# Case Number
# Date
# Year
# Type
# Country
# Area
# Location
# Activity
# Name
# Sex
# Age
# Injury
# Fatal (Y/N)
# Time
# Species
# Investigator or Source
# pdf
# href formula
# href
# Case Number.1
# Case Number.2
# original order
# Unnamed: 22
# Unnamed: 23

# %%
attack1 = attack.drop(columns = ['Unnamed: 22','Unnamed: 23'])
attackCountry = attack1['Country'].value_counts()
display(attackCountry)
# Out:
# USA                 2229
# AUSTRALIA           1338
# SOUTH AFRICA         579
# PAPUA NEW GUINEA     134
# NEW ZEALAND          128
#                     ...
# MAYOTTE                1
# CYPRUS                 1
# GULF OF ADEN           1
# COOK ISLANDS           1
# ST. MARTIN             1
# Name: Country, Length: 212, dtype: int64

# %%
print(attack['Injury'][450:501])
# Out:
# 450            5 minor puncture wounds to lower left leg
# 451              No injury, shark's teeth scratched hull
# 452    Lacerations to calf by hooked shark PROVOKED I...
# 453                          No injury, surfboard dented
# 454                                          Foot bitten
# 455    No injury but shark bit trolling motor & ramme...
# 456                                 Board snapped in two
# 457            Shark bumped boat, no injury to occupants
# 458                               Bitten on hand & wrist
# 459    During his 16-hour swim to shore, he was circl...
# 460                           Severe bite to right flank
# 461    Lacerations to lower left leg, puncture wounds...
# 462                                           Leg bitten
# 463                             Lacerations to both feet
# 464                                                FATAL
# 465     Of 9 bodies recovered, one was bitten by a shark
# ...
